# %%
import jax

jax.config.update("jax_enable_x64", True)

from jax import numpy as jnp

# %%
jax.__version__
# Out:
# '0.6.2'

# %%
import os

# %%
from jaxpip.descriptor import PolynomialDescriptor

# %%
_ALPHA = 1.0

# %%
pip_a6b2c_6 = PolynomialDescriptor.from_file(
    basis_file=os.path.join("A6B2C_6", "MOL_6_2_1_6.json.gz"),
    alpha=_ALPHA,
    with_grad=False,
    dtype=jnp.float64,
)

pip_a6b2c_6
# Out:
# PolynomialDescriptor(
#   num_flat_exponents=5245786,
#   num_atoms=9,
#   num_pips=14483,
#   dtype=<class 'jax.numpy.float64'>,
#   with_grad=False
# )

# %%
pip_a6b2c_6_with_grad = PolynomialDescriptor.from_file(
    basis_file=os.path.join("A6B2C_6", "MOL_6_2_1_6.json.gz"),
    alpha=_ALPHA,
    with_grad=True,
    dtype=jnp.float64,
)

pip_a6b2c_6_with_grad
# Out:
# PolynomialDescriptor(
#   num_flat_exponents=5245786,
#   num_atoms=9,
#   num_pips=14483,
#   dtype=<class 'jax.numpy.float64'>,
#   with_grad=True
# )
